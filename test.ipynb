# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
df = pd.read_csv("data/train/stocks/AAPL.csv")

# %%
df
# Out:
#             Date Ticker        Open        High         Low       Close  \
# 0     2015-01-05   AAPL   27.072500   27.162500   26.352501   26.562500
# 1     2015-01-06   AAPL   26.635000   26.857500   26.157499   26.565001
# 2     2015-01-07   AAPL   26.799999   27.049999   26.674999   26.937500
# 3     2015-01-08   AAPL   27.307501   28.037500   27.174999   27.972500
# 4     2015-01-09   AAPL   28.167500   28.312500   27.552500   28.002501
# ...          ...    ...         ...         ...         ...         ...
# 2564  2025-03-17   AAPL  213.309998  215.220001  209.970001  214.000000
# 2565  2025-03-18   AAPL  214.160004  215.149994  211.490005  212.690002
# 2566  2025-03-19   AAPL  214.220001  218.759995  213.750000  215.240005
# 2567  2025-03-20   AAPL  213.990005  217.490005  212.220001  214.100006
# 2568  2025-03-21   AAPL  211.559998  218.839996  211.279999  218.270004
#
#         Adjusted   Returns     Volume
# 0      23.635283 -0.028172  257142000
# 1      23.637512  0.000094  263188400
# 2      23.968964  0.014022  160423600
# 3      24.889904  0.038422  237458000
# 4      24.916595  0.001072  214798000
# ...          ...       ...        ...
# 2564  214.000000  0.002389   48073400
# 2565  212.690002 -0.006121   42432400
# 2566  215.240005  0.011989   54385400
# 2567  214.100006 -0.005296   48862900
# 2568  218.270004  0.019477   94127800
#
# [2569 rows x 9 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close     Adjusted  \
# count  2569.000000  2569.000000  2569.000000  2569.000000  2569.000000
# mean     99.171759   100.233816    98.177228    99.258384    97.118032
# std      67.409430    68.121183    66.749477    67.480909    67.954795
# min      22.500000    22.917500    22.367500    22.584999    20.674528
# 25%      38.302502    38.497501    37.877499    38.285000    35.827236
# 50%      70.449997    71.457497    69.699997    70.792503    68.719414
# 75%     156.979996   158.740005   154.410004   156.899994   154.839844
# max     258.190002   260.100006   257.630005   259.019989   258.735504
#
#            Returns        Volume
# count  2569.000000  2.569000e+03
# mean      0.001016  1.157259e+08
# std       0.017942  6.830528e+07
# min      -0.128647  2.323470e+07
# 25%      -0.007398  6.967280e+07
# 50%       0.000951  9.844480e+07
# 75%       0.010139  1.411475e+08
# max       0.119808  6.488252e+08

# %%
df_test = pd.read_csv("data/test/test_1.csv")
df_test
# Out:
#             Date        Open        High         Low       Close    Adjusted  \
# 0     2015-01-05   55.889999   57.520000   55.639999   56.990002   56.990002
# 1     2015-01-06   57.330002   57.939999   56.790001   57.450001   57.450001
# 2     2015-01-07   57.970001   59.750000   57.450001   59.570000   59.570000
# 3     2015-01-08   60.000000   61.669998   59.740002   61.439999   61.439999
# 4     2015-01-09   61.669998   62.820000   61.500000   62.580002   62.580002
# ...          ...         ...         ...         ...         ...         ...
# 2564  2025-03-17  166.199997  171.520004  165.289993  169.589996  169.589996
# 2565  2025-03-18  168.000000  170.089996  163.440002  164.529999  164.529999
# 2566  2025-03-19  164.149994  168.139999  162.580002  166.139999  166.139999
# 2567  2025-03-20  165.169998  170.729996  163.899994  168.809998  168.809998
# 2568  2025-03-21  165.809998  169.449997  163.240005  168.610001  168.610001
#
#        Returns   Volume
# 0     0.014057   593600
# 1     0.008072   825000
# 2     0.036902  1053500
# 3     0.031392  1289100
# 4     0.018555  1549400
# ...        ...      ...
# 2564  0.020397  1029500
# 2565 -0.029837  1255700
# 2566  0.009785  1390600
# 2567  0.016071  1228000
# 2568 -0.001185  1881400
#
# [2569 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(range(2569), df["Returns"])

# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np

# %%
aapl = df[["Open", "High", "Low", "Close", "Adjusted", "Volume"]]
# data = aapl.to_numpy()

# %%
# def create_batches(input_data, batch_size=10):
#     data = input_data.to_numpy()
#     total_full_batches = len(data) // batch_size  # only full batches
#     trimmed_data = data[:total_full_batches * batch_size]  # discard leftover
#     batches = trimmed_data.reshape(total_full_batches, batch_size, -1)
#     return batches

X = aapl.to_numpy()
Y = df[["Returns"]].to_numpy()

X = X[:-10]
Y = Y[10:]

# %%
X.shape
# Out:
# (2559, 6)

# %%
Y.shape
# Out:
# (2559, 1)

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()
